# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('hh_200_150_300_0_1.dat',sep=',',header=None,comment='#')
X=df.drop([0,1],axis=1)
X.columns = range(X.shape[1])
width = df[0]
width=np.mean(width) #actually all equal
x=np.mean(X,axis=0)
hgt=(x/np.sum(x))/width
thr=np.arange(X.shape[1])*width
plt.bar(x=thr,width=width,align='edge',height=hgt)
# Out:
# <BarContainer object of 300 artists>

# %%
plt.plot(thr, hgt)

# %%
np.savetxt('rmt_pdf.txt', np.concatenate((thr.reshape(-1,1)[1:], hgt.values.reshape(-1,1)[1:]), axis=1))

# %%
import scipy.optimize as opt

# %%
p,_=opt.curve_fit(wisurm, thr, hgt.values)
plt.scatter(thr, hgt)
plt.plot(np.linspace(0,4), wisurm(np.linspace(0,4), p[0], p[1],p[2], p[3]), c='orangered')
plt.plot(np.linspace(0,4), wisurm(np.linspace(0,4), 32/(np.pi**2), 2,4/np.pi,2), c='green')
p
# Out:
# /home/vicio/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in power
# array([4.03739212, 2.09291644, 1.51588543, 1.81590167])

# %%
R=pd.read_csv('hr_2000_150_300_0.dat',sep=',',header=None,comment='#')
R.columns = range(R.shape[1])
r = np.mean(R, axis=0)
plt.hist(1-r, 50)
plt.show()
print(np.mean(r),'+/-', np.std(r))
plt.plot(r)
# Out:
# 0.997629615836002 +/- 0.00955221768590895
