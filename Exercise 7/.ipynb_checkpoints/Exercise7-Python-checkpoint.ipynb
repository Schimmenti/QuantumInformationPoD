# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
fig, ax = plt.subplots()
fig.set_tight_layout(True)
psi_r = np.loadtxt('wf_real.dat', delimiter=',')
psi_i = np.loadtxt('wf_imag.dat', delimiter=',')
line, = ax.plot((psi_r[:,0]**2+psi_i[:,0]**2))
line2, = ax.plot(0.5*(1E-5)*(np.arange(1000)-500)**2)

# %%
def update(i):
    label = 'timestep {0}'.format(i)
    line.set_ydata((psi_r[:,i]**2+psi_i[:,i]**2))
    line2.set_ydata(0.5*(1E-5)*(np.arange(1000)-500+i)**2)
    ax.set_xlabel(label)
    return line, ax

# %%
anim = FuncAnimation(fig, update, frames=np.arange(0, 100), interval=200)
anim.save('wave.gif', dpi=80, writer='imagemagick')
